# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from sklearn.cluster import KMeans

# %%
iris = pd.read_csv('iris.csv').iloc[:,1:]

# %%
iris
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
iris['Species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
plt.scatter(iris['Petal.Width'],iris['Petal.Length'])

# %%
col = pd.Series(iris['Species']).map({'setosa':'r','versicolor':'b','virginica':'g'})
plt.scatter(iris['Petal.Width'],iris['Petal.Length'],c=col)

# %%
kmeans = KMeans(n_clusters=3)
col = pd.Series(kmeans.fit(iris.iloc[:,0:4]).labels_).map({0:'r',1:'b',2:'g'})
plt.scatter(iris['Petal.Width'],iris['Petal.Length'],c=col)

# %%
KMeans(n_clusters=4).fit(iris.iloc[:,0:4]).inertia_
# Out:
# 57.228473214285714

# %%
sse = []
for i in range(1,10) :
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(iris.iloc[:,0:4])
    sse.append(kmeans.inertia_)

# %%
[i for i in [KMeans(n_clusters=k).fit(iris.iloc[:,0:4]).inertia_ for k in range(10)]]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py:90: RuntimeWarning: divide by zero encountered in log
#   n_local_trials = 2 + int(np.log(n_clusters))
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-13-fe6e182c1844> in <module>
# ----> 1 [i for i in [KMeans(n_clusters=k).fit(iris.iloc[:,0:4]).inertia_ for k in range(10)]]
#
# <ipython-input-13-fe6e182c1844> in <listcomp>(.0)
# ----> 1 [i for i in [KMeans(n_clusters=k).fit(iris.iloc[:,0:4]).inertia_ for k in range(10)]]
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py in fit(self, X, y, sample_weight)
#     967                 tol=self.tol, random_state=random_state, copy_x=self.copy_x,
#     968                 n_jobs=self.n_jobs, algorithm=self.algorithm,
# --> 969                 return_n_iter=True)
#     970         return self
#     971
#
# ...

# %%
plt.plot(range(1,10),sse)
plt.plot(np.linspace(3,3,6),np.linspace(-1,700,6),'--')
