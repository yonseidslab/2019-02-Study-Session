# %% [markdown]
# # 패키지 및 데이터 불러오기

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
from sklearn.cluster import KMeans, AgglomerativeClustering,DBSCAN

# %%
clustering_dt = pd.read_excel('sbs데이터_20190708_1.xlsx',encoding='euc-kr')
clustering_dt.head()
# Out:
#      program   10대   20대    30대    40대   50대   60대  70대  80대  90대    SMR  \
# 0      태양의계절   879  2756   4883   8304  4940  1355  103   22    0  23242
# 1       트래블러     5    42     32      8    22     0    0    0    0    109
# 2     티엠아이뉴스   165    94     62      6    14     0    2    0    0    343
# 3         퍼퓸  3742  7959  11806  14423  3054   404   78   25    0  41491
# 4  평일오후세시의연인   629  2677   8822  13604  2636   265   67   15    0  28715
#
#    blog  community  news   search  twitter  woman   man
# 0     1          2     7  1105300    0.671  20352  2890
# 1     0          0     0    17120    0.000    101     8
# 2     0          0     0     7830    0.000    243   100
# 3     5          1    73  1135900   28.000  38421  3070
# 4     2          0    10  1387600   15.000  26708  2007

# %% [markdown]
# ### 변수 설명
# - SMR : 방송콘텐츠 접근량
# - blog/community/news/twitter : 방송콘텐츠 관련 언급량
# - search : N사이트 검색량
# - man/woman : 성별 smr count
# - 10대/.../90대 : 연령별 smr count

# %% [markdown]
# # 데이터 EDA

# %%
plt.scatter(clustering_dt.woman,clustering_dt.man, label='True Position')

# %%
plt.scatter(clustering_dt['30대'],clustering_dt['50대'], label='True Position')

# %%
plt.scatter(clustering_dt['twitter'],clustering_dt['news'], label='True Position')

# %%
plt.scatter(clustering_dt['10대'],clustering_dt['90대'], label='True Position')

# %% [markdown]
# # 클러스터링

# %%
kmeans = KMeans()
X = clustering_dt.loc[:,'10대':'man']

# %%
sse = []
for i in range(1,10) :
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(X)
    sse.append(kmeans.inertia_)

# %%
sse = [KMeans(n_clusters=i).fit(X).inertia_ for i in range(1,10)]

# %%
plt.plot(range(1,10),sse)

# %%
kmeans = KMeans(n_clusters=4)

# %%
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[5.54948980e+02, 1.91586735e+03, 2.97836735e+03, 3.51388776e+03,
#         1.28918367e+03, 2.50163265e+02, 4.10714286e+01, 8.88775510e+00,
#         5.30612245e-01, 1.05529184e+04, 2.93877551e+00, 1.78571429e+00,
#         1.05204082e+01, 1.84558061e+05, 2.30888163e+01, 7.73924490e+03,
#         2.81367347e+03],
#        [1.42818000e+05, 2.07522500e+05, 2.20079000e+05, 1.96447500e+05,
#         4.62810000e+04, 1.10780000e+04, 1.42550000e+03, 3.56000000e+02,
#         3.20000000e+01, 8.26039500e+05, 2.10000000e+01, 8.50000000e+00,
#         4.30000000e+01, 6.56008000e+06, 1.51432500e+02, 7.46267000e+05,
#         7.97725000e+04],
#        [5.67812500e+03, 1.68377500e+04, 2.11306250e+04, 2.41147500e+04,
#         6.92012500e+03, 1.13300000e+03, 2.27375000e+02, 2.92500000e+01,
#         1.00000000e+00, 7.60720000e+04, 5.62500000e+00, 8.37500000e+00,
#         2.41250000e+01, 2.53328750e+06, 6.16016250e+01, 6.81817500e+04,
#         7.89025000e+03],
#        [7.12605000e+03, 2.52277000e+04, 2.31811000e+04, 2.97477000e+04,
#         1.34310500e+04, 1.84610000e+03, 2.88800000e+02, 6.85000000e+01,
#         2.90000000e+00, 1.00919900e+05, 4.10000000e+00, 1.35000000e+01,
#         2.43500000e+01, 1.31238000e+06, 5.09335500e+01, 8.37131000e+04,
#         1.72068000e+04]])

# %%
clustering_dt.columns[1:]
# Out:
# Index(['10대', '20대', '30대', '40대', '50대', '60대', '70대', '80대', '90대', 'SMR',
#        'blog', 'community', 'news', 'search', 'twitter', 'woman', 'man'],
#       dtype='object')

# %%
pd.DataFrame(kmeans.cluster_centers_,columns=clustering_dt.columns[1:],index=['1번','2번','3번','4번'])
# Out:
#              10대            20대            30대            40대           50대  \
# 1번     554.94898    1915.867347    2978.367347    3513.887755   1289.183673
# 2번  142818.00000  207522.500000  220079.000000  196447.500000  46281.000000
# 3번    5678.12500   16837.750000   21130.625000   24114.750000   6920.125000
# 4번    7126.05000   25227.700000   23181.100000   29747.700000  13431.050000
#
#              60대          70대         80대        90대            SMR  \
# 1번    250.163265    41.071429    8.887755   0.530612   10552.918367
# 2번  11078.000000  1425.500000  356.000000  32.000000  826039.500000
# 3번   1133.000000   227.375000   29.250000   1.000000   76072.000000
# 4번   1846.100000   288.800000   68.500000   2.900000  100919.900000
#
#          blog  community       news        search     twitter          woman  \
# 1번   2.938776   1.785714  10.520408  1.845581e+05   23.088816    7739.244898
# 2번  21.000000   8.500000  43.000000  6.560080e+06  151.432500  746267.000000
# 3번   5.625000   8.375000  24.125000  2.533288e+06   61.601625   68181.750000
# 4번   4.100000  13.500000  24.350000  1.312380e+06   50.933550   83713.100000
#
#              man
# 1번   2813.673469
# 2번  79772.500000
# 3번   7890.250000
# 4번  17206.800000

# %%
plt.scatter(clustering_dt['twitter'],clustering_dt['news'], c=kmeans.labels_,label='True Position')

# %%
plt.scatter(clustering_dt['30대'],clustering_dt['SMR'], c=kmeans.labels_,label='True Position')

# %%
Label=pd.DataFrame(kmeans.labels_,columns=['label'])
r=pd.concat([clustering_dt,Label],axis=1)

# %%
import seaborn as sns
sns.pairplot(r,hue='label')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)

# %%
plt.scatter(clustering_dt['search'],clustering_dt['woman'], c=kmeans.labels_,label='True Position')

# %%
plt.scatter(clustering_dt['blog'],clustering_dt['search'], c=kmeans.labels_, label='True Position')

# %% [markdown]
# # 결과분석

# %%
names=clustering_dt['program']
result=pd.concat([names,Label],axis=1)
print(result)
# Out:
#           program  label
# 0           태양의계절      3
# 1            트래블러      0
# 2          티엠아이뉴스      0
# 3              퍼퓸      3
# 4       평일오후세시의연인      3
# 5        풀뜯어먹는소리3      0
# 6        프로듀스x101      1
# 7             하우스      0
# 8          해피투게더4      0
# 9          코미디빅리그      0
# 10     현지에서먹힐까미국편      0
# 11       호구들의감빵생활      0
# 12          호구의연애      3
# 13       회사가기싫어정규      0
# 14          바람이분다      2
# 15          방구석1열      0
# 16           배틀트립      0
# 17           한끼줍쇼      0
# 18           취존생활      0
# 19           찰떡콤비      0
# 20       초면에사랑합니다      3
# 21         보이스시즌3      3
# 22         위대한수제자      0
# 23           유학소녀      0
# 24        으라차차만수로      0
# 25     이규연의스포트라이트      0
# 26             이몽      0
# 27      이상한나라의며느리      0
# 28            작업실      0
# 29            장보고      0
# ..            ...    ...
# 98     살림하는남자들시즌2      0
# 99    사장님귀는당나귀귀정규      0
# 100         불후의명곡      0
# 101         불타는청춘      0
# 102        부라더시스터      0
# 103            봄밤      2
# 104         생활의달인      0
# 105  2018tv는사랑을싣고      0
# 106      슈퍼맨이돌아왔다      3
# 107         슈퍼히어러      0
# 108       우리집에왜왔니      0
# 109       용왕님보우하사      0
# 110            왓쳐      3
# 111    옥탑방의문제아들정규      0
# 112        오늘밤김제동      0
# 113         영재발굴단      0
# 114         연예가중계      0
# 115       연애의맛시즌2      0
# 116          슈퍼밴드      3
# 117        여름아부탁해      3
# 118           어비스      3
# 119          애들생각      0
# 120    아이를위한나라는있다      0
# 121        아스달연대기      1
# 122          아는형님      3
# 123          썸바이벌      0
# 124       실화탐사대정규      0
# 125         스테이지k      0
# 126   어서와한국은처음이지2      0
# 127          복면가왕      0
#
# [128 rows x 2 columns]

# %%
label_unique = result['label'].unique()
grouping = result.groupby(['label'])
res = [ {'programs': result.loc[grouping.groups[l]]['program'].tolist()} for l in label_unique]
result_grouped = pd.DataFrame(res,index=[str(l) + '번' for l in label_unique])
result_grouped
# Out:
#                                              programs
# 3번  [태양의계절, 퍼퓸, 평일오후세시의연인, 호구의연애, 초면에사랑합니다, 보이스시즌3...
# 0번  [트래블러, 티엠아이뉴스, 풀뜯어먹는소리3, 하우스, 해피투게더4, 코미디빅리그, ...
# 1번                                 [프로듀스x101, 아스달연대기]
# 2번  [바람이분다, 나혼자산다, 그것이알고싶다, 검색어를입력하세요www, 60일지정생존자...

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure (figsize=(6,6))
ax = Axes3D(fig,rect=[0,0,0.95,1],elev=48,azim=134)
ax.scatter(r['search'],r['woman'],r['20대'],c=r['label'],alpha=0.5)
ax.set_xlabel('search')
ax.set_ylabel('woman')
ax.set_zlabel('20대')
plt.show()

# %%
fig = plt.figure (figsize=(6,6))
ax = Axes3D(fig,rect=[0,0,0.95,1],elev=48,azim=134)
ax.scatter(r['search'],r['blog'],r['40대'],c=r['label'],alpha=0.5)
ax.set_xlabel('search')
ax.set_ylabel('twitter')
ax.set_zlabel('20대')
plt.show()

# %%
def doAgglomerative(X, nclust=4):
    model = AgglomerativeClustering(n_clusters=nclust, affinity = 'euclidean', linkage = 'ward')
    clust_labels1 = model.fit_predict(X)
    return (clust_labels1)

clust_labels1 = doAgglomerative(X, 4)
agglomerative = pd.DataFrame(clust_labels1)
X.insert((X.shape[1]),'agglomerative',agglomerative)
fig = plt.figure()
ax = fig.add_subplot(111)
scatter = ax.scatter(X['10대'],X['search'],
                     c=agglomerative[0],s=50)
ax.set_title('Agglomerative Clustering')
ax.set_xlabel('10대')
ax.set_ylabel('search')
plt.colorbar(scatter)

# %% [markdown]
#  AGNES도 유사한 결과물
#  클러스터링 결과를 기반으로 Search 를 상중하로 나누어 심플하게 만들 수도 있음
